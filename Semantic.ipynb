# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Input text
text = "The cat is chasing the mouse across the garden."

# Tokenization and stopword removal
tokens = word_tokenize(text)
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# Define the function properly
def get_semantic_relationships(word):
    synsets = wn.synsets(word)   # <-- here synsets is properly created

    if not synsets:
        print(f"No synsets found for: {word}")
        return

    print(f"Semantic relationships for the word '{word}':\n")

    for synset in synsets:
        print(f"Synset: {synset.name()}")

        synonyms = synset.lemmas()
        print(f"  Synonyms: {[lemma.name() for lemma in synonyms]}")

        antonyms = [lemma.name() for lemma in synonyms if lemma.antonyms()]
        if antonyms:
            print(f"  Antonyms: {antonyms}")

        hypernyms = synset.hypernyms()
        print(f"  Hypernyms: {[hypernym.name() for hypernym in hypernyms]}")

        hyponyms = synset.hyponyms()
        print(f"  Hyponyms: {[hyponym.name() for hyponym in hyponyms]}")

        print("-" * 50)

# Apply the function on each filtered word
for word in filtered_tokens:
    get_semantic_relationships(word)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sagar
# [nltk_data]     kharade\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sagar
# [nltk_data]     kharade\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\sagar
# [nltk_data]     kharade\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\sagar
# [nltk_data]     kharade\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Semantic relationships for the word 'cat':
#
# Synset: cat.n.01
#   Synonyms: ['cat', 'true_cat']
#   Hypernyms: ['feline.n.01']
#   Hyponyms: ['domestic_cat.n.01', 'wildcat.n.03']
# --------------------------------------------------
# Synset: guy.n.01
#   Synonyms: ['guy', 'cat', 'hombre', 'bozo']
#   Hypernyms: ['man.n.01']
#   Hyponyms: ['sod.n.04']
# --------------------------------------------------
# Synset: cat.n.03
#   Synonyms: ['cat']
#   Hypernyms: ['gossip.n.03', 'woman.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: kat.n.01
#   Synonyms: ['kat', 'khat', 'qat', 'quat', 'cat', 'Arabian_tea', 'African_tea']
#   Hypernyms: ['stimulant.n.02']
#   Hyponyms: []
# --------------------------------------------------
# Synset: cat-o'-nine-tails.n.01
#   Synonyms: ["cat-o'-nine-tails", 'cat']
#   Hypernyms: ['whip.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: caterpillar.n.02
#   Synonyms: ['Caterpillar', 'cat']
#   Hypernyms: ['tracked_vehicle.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: big_cat.n.01
#   Synonyms: ['big_cat', 'cat']
#   Hypernyms: ['feline.n.01']
#   Hyponyms: ['cheetah.n.01', 'jaguar.n.01', 'leopard.n.02', 'liger.n.01', 'lion.n.01', 'saber-toothed_tiger.n.01', 'snow_leopard.n.01', 'tiger.n.02', 'tiglon.n.01']
# --------------------------------------------------
# Synset: computerized_tomography.n.01
#   Synonyms: ['computerized_tomography', 'computed_tomography', 'CT', 'computerized_axial_tomography', 'computed_axial_tomography', 'CAT']
#   Hypernyms: ['x-raying.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: cat.v.01
#   Synonyms: ['cat']
#   Hypernyms: ['flog.v.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: vomit.v.01
#   Synonyms: ['vomit', 'vomit_up', 'purge', 'cast', 'sick', 'cat', 'be_sick', 'disgorge', 'regorge', 'retch', 'puke', 'barf', 'spew', 'spue', 'chuck', 'upchuck', 'honk', 'regurgitate', 'throw_up']
#   Antonyms: ['vomit']
#   Hypernyms: ['excrete.v.01']
#   Hyponyms: []
# --------------------------------------------------
# Semantic relationships for the word 'chasing':
#
# Synset: chase.v.01
#   Synonyms: ['chase', 'chase_after', 'trail', 'tail', 'tag', 'give_chase', 'dog', 'go_after', 'track']
#   Hypernyms: ['pursue.v.02']
#   Hyponyms: ['hound.v.01', 'quest.v.02', 'run_down.v.07', 'tree.v.03']
# --------------------------------------------------
# Synset: chase.v.02
#   Synonyms: ['chase', 'chase_after']
#   Hypernyms: ['woo.v.02']
#   Hyponyms: []
# --------------------------------------------------
# Synset: chase.v.03
#   Synonyms: ['chase']
#   Hypernyms: ['cut.v.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: furrow.v.03
#   Synonyms: ['furrow', 'chamfer', 'chase']
#   Hypernyms: ['cut.v.01']
#   Hyponyms: []
# --------------------------------------------------
# Semantic relationships for the word 'mouse':
#
# Synset: mouse.n.01
#   Synonyms: ['mouse']
#   Hypernyms: ['rodent.n.01']
#   Hyponyms: ['field_mouse.n.02', 'harvest_mouse.n.02', 'house_mouse.n.01', 'nude_mouse.n.01', 'wood_mouse.n.01']
# --------------------------------------------------
# Synset: shiner.n.01
#   Synonyms: ['shiner', 'black_eye', 'mouse']
#   Hypernyms: ['bruise.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: mouse.n.03
#   Synonyms: ['mouse']
#   Hypernyms: ['person.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: mouse.n.04
#   Synonyms: ['mouse', 'computer_mouse']
#   Hypernyms: ['electronic_device.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: sneak.v.01
#   Synonyms: ['sneak', 'mouse', 'creep', 'pussyfoot']
#   Hypernyms: ['walk.v.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: mouse.v.02
#   Synonyms: ['mouse']
#   Hypernyms: ['manipulate.v.02']
#   Hyponyms: []
# --------------------------------------------------
# Semantic relationships for the word 'across':
#
# Synset: across.r.01
#   Synonyms: ['across']
#   Hypernyms: []
#   Hyponyms: []
# --------------------------------------------------
# Synset: across.r.02
#   Synonyms: ['across', 'crosswise', 'crossways']
#   Hypernyms: []
#   Hyponyms: []
# --------------------------------------------------
# Semantic relationships for the word 'garden':
#
# Synset: garden.n.01
#   Synonyms: ['garden']
#   Hypernyms: ['plot.n.02']
#   Hyponyms: ['flower_garden.n.01', 'formal_garden.n.01', 'grove.n.02', 'herb_garden.n.01', 'hop_garden.n.01', 'kitchen_garden.n.01', 'landscaping.n.02', 'market_garden.n.01', 'pot_farm.n.01', 'rock_garden.n.01', 'roof_garden.n.01', 'rose_garden.n.01', 'sunken_garden.n.01', 'tea_garden.n.01', 'topiary.n.01']
# --------------------------------------------------
# Synset: garden.n.02
#   Synonyms: ['garden']
#   Hypernyms: ['vegetation.n.01']
#   Hyponyms: []
# --------------------------------------------------
# Synset: garden.n.03
#   Synonyms: ['garden']
#   Hypernyms: ['yard.n.02']
#   Hyponyms: []
# --------------------------------------------------
# Synset: garden.v.01
#   Synonyms: ['garden']
#   Hypernyms: ['tend.v.02']
#   Hyponyms: ['landscape.v.02']
# --------------------------------------------------
# No synsets found for: .
